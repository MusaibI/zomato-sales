# %%
#Importing libraries whch are to be used in further analysis process
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato_df=pd.read_csv('d:/DATA SETS/zomato.csv',encoding='latin_1')# importing data into dataframe

# %%
zomato_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
len(zomato_df) # Checking no.of rows in the dataset
# Out:
# 9551

# %%
zomato_df.columns # Columns name is displayed
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
zomato_df.shape
# Out:
# (9551, 21)

# %%
zomato_df.info() # Information about the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
zomato_df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ### Observation:- There are 9 null values in the column 'Cuisines'

# %% [markdown]
# ### Since Cuisine is a Categorical data , therefore rows with null values are droped

# %%
zomato_df.dropna(axis=0,subset=['Cuisines'],inplace=True)

# %%
zomato_df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %% [markdown]
# ### We have another Dataset which has the data about country codes

# %%
country_df=pd.read_excel('d:/DATA SETS/Country-Code.xlsx')

# %%
country_df
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# ### Observation:- Zomato service is spread across 15 countries

# %% [markdown]
# ### Merging of two datasetes:
# ### 1.Zomato_df   2.Country_code

# %%
df=pd.merge(zomato_df,country_df,on='Country Code')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#Since we have the country no need of country code
#Dropping country code column

# %%
df.drop('Country Code',axis=1,inplace=True)

# %% [markdown]
# # Exploring Dataset

# %% [markdown]
# ### In data analysis what things we do
# 1) missing values
#
# 2) explore about numerical variables
#
# 3) explore about categories variables
#
# 4) finding relationship between features/columns

# %%
df.groupby('Country').size().sort_values(ascending=False)
# Out:
# Country
# India             8652
# United States      425
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# dtype: int64

# %% [markdown]
# ### Observation:- India has Highest number of resturants on Zomato

# %%
a=pd.DataFrame(df['Country'].value_counts().reset_index())

# %%
a.columns=['Countries','No.Of Resturants']

# %%
a.index=[i for i in range(1,16)]

# %%
a
# Out:
#          Countries  No.Of Resturants
# 1            India              8652
# 2    United States               425
# 3   United Kingdom                80
# 4           Brazil                60
# 5              UAE                60
# 6     South Africa                60
# 7      New Zealand                40
# 8           Turkey                34
# 9        Australia                24
# 10     Phillipines                22
# 11       Indonesia                21
# 12       Singapore                20
# 13           Qatar                20
# 14       Sri Lanka                20
# 15          Canada                 4

# %%
df.groupby(['Aggregate rating','Rating color','Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %% [markdown]
# ### Observation:- There are more no.of people who didn't rated
#      **Rating     ** Color      **Text
#      4.5-4.9       Dark Green   Excellent
#      4.1-4.4       Green        Very Good
#      3.5-3.9       Yellow       Good
#      2.5-3.4       Orange       Average
#      1.8-2.4       Red          Poor

# %%
Indian_rest=df[df['Country']=='India']

# %%
Indian_rest
# Out:
#       Restaurant ID                        Restaurant Name   City  \
# 615         3400025                             Jahanpanah   Agra
# 616         3400341                    Rangrezz Restaurant   Agra
# 617         3400005                Time2Eat - Mama Chicken   Agra
# 618         3400021  Chokho Jeeman Marwari Jain Bhojanalya   Agra
# 619         3400017                         Pinch Of Spice   Agra
# ...             ...                                    ...    ...
# 9262        2800100                               D Cabana  Vizag
# 9263        2800418                               Kaloreez  Vizag
# 9264        2800881                                Plot 17  Vizag
# 9265        2800042                       Vista - The Park  Vizag
# 9266        2800019               Flying Spaghetti Monster  Vizag
#
#                                                 Address  \
# 615   E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 616   E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# ...

# %%
Indian_rest.groupby('Aggregate rating').size()
# Out:
# Aggregate rating
# 0.0    2139
# 1.8       1
# 1.9       2
# 2.0       7
# 2.1      15
# 2.2      26
# 2.3      46
# 2.4      83
# 2.5     109
# 2.6     190
# 2.7     250
# 2.8     314
# 2.9     380
# 3.0     465
# 3.1     511
# 3.2     510
# 3.3     472
# 3.4     477
# 3.5     454
# 3.6     411
# 3.7     363
# 3.8     336
# 3.9     283
# 4.0     193
# 4.1     185
# 4.2     140
# 4.3     100
# 4.4      74
# 4.5      37
# 4.6      35
# 4.7      16
# 4.8       9
# 4.9      19
# dtype: int64

# %%
df[df['Has Online delivery']=='Yes'].groupby('Country').size()
# Out:
# Country
# India    2423
# UAE        28
# dtype: int64

# %% [markdown]
# ### Only India and UAE has Home Delivery Option

# %%
df['Price range'].unique() # Finding unique values in the column price range
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %%
df[df['Price range']==4].groupby('Country').size() #No of Resturants having 4 star across the countries
# Out:
# Country
# Australia           1
# Brazil             35
# Canada              1
# India             388
# New Zealand        16
# Phillipines         9
# Qatar              14
# Singapore          14
# South Africa       39
# Sri Lanka           3
# Turkey              5
# UAE                22
# United Kingdom     16
# United States      23
# dtype: int64

# %%
Indian_rest.groupby('Price range').size()  # Segregating Indian Resturants baesd on the rating
# Out:
# Price range
# 1    4295
# 2    2858
# 3    1111
# 4     388
# dtype: int64

# %% [markdown]
# ### Observaton:- In India more resturants are having  poor rating

# %% [markdown]
# #

# %% [markdown]
# ##

# %% [markdown]
# # Ploting Of Graphs

# %%
df.groupby(['Aggregate rating']).size().plot()
# Out:
# <AxesSubplot:xlabel='Aggregate rating'>

# %%
plt.figure(figsize=(10,8))
df.groupby(['Aggregate rating']).size().plot(kind='bar')
plt.ylabel('Rating count',fontsize=12)
plt.xlabel('Aggregate Rating',fontsize=12)
plt.show()

# %% [markdown]
# ### More resturants are in the mid range
